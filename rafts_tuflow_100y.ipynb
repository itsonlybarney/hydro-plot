# %% [markdown]
# ## Graphing TUFLOW
#
# Convert __*modelname_event_scenario_PO.csv*__ files into graphs for reports

# %% [markdown]
# ###### Python Imports
# * Import NumPy, Pandas and Matplotlib

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib notebook
matplotlib.rcParams['figure.figsize'] = [8,5]

# %% [markdown]
# ###### Load Files
# * Change to file names uploaded through file manager

# %%
df_dataset_s00 = pd.read_csv('tuflow_100y/UpperSthCk_CR_100y2hr_004_PO.csv', skiprows = 1)
df_dataset_s01 = pd.read_csv('rafts_100y/142-15_DA_s00_002_100y120m_tot.ts1', skiprows = 8)

# %% [markdown]
# ###### Create Time Series'
# Note: May need to convert units if comparing different models

# %%
dataset_s00_timeseries = df_dataset_s00['Time'].tolist()
dataset_s01_timeseries = df_dataset_s01['Time (min)'].tolist()

# %% [markdown]
# ###### Create Data Series'
# * Select 'sample_point' from the column titles
# * Convert column into a list for Matplotlib

# %%
# Hydrographs
#sample_point = 'Bonds_DS_Rickard'
#sample_point = 'C 1-5'
sample_point = 'C 1-3'

values_s00 = df_dataset_s00[sample_point].tolist()
values_s01 = df_dataset_s01['F 1-3'].tolist()

# %% [markdown]
# ###### Setup Graphs using Matplotlib
# * Matplotlib basic setup
# * Set Plot Title
# * Set Series Titles
# * Set Max/Min for Time Series'
# * Font Styling
# * Create Plot
# * Display Plot

# %%
plot_title = 'Model Comparison - 100y ARI 2hr Duration - {}'.format(sample_point)
plot_label_s00 = 'C&R 142-15 (TUFLOW Rain-on-Grid) - Pre-development'
plot_label_s01 = "RAFTS - 100y ARI 120min - Pre"
min_time = 0
max_time = 240  # in minutes

# Graph Styling
fontlarge = {'family': 'sans-serif',
              'color': 'black',
              'weight': 'bold',
              'size': 14,
              }
fontsmall = {'family': 'sans-serif',
              'color':  'black',
              'weight': 'normal',
              'size': 11,
              }
plt.style.use('bmh')

plt.title(plot_title, fontdict = fontlarge)

plt.xlabel('Time ($min$)', fontdict = fontsmall)
plt.xlim(min_time, max_time)
plt.xticks(np.arange(min_time, max_time + 1, 15))

plt.ylabel('Discharge ($m^3/s$)', fontdict = fontsmall)

plt.plot(dataset_s00_timeseries, values_s00, label = plot_label_s00)
plt.plot(dataset_s01_timeseries, values_s01, label = plot_label_s01)

plt.legend(loc = 1)

filename = 'tuflow_100y/plot_{}.png'.format(sample_point)
plt.savefig(filename, dpi = 100)
plt.show()

# %% [markdown]
# ###### Display Peak Flow Rates for Location

# %%
print('Peak Discharge (cu.m/s)')
print('Pre-Dev: ', np.max(df_dataset_s00[sample_point]))
print('Pre-Dev: ', np.max(df_dataset_s01[sample_point]))
# Out:
# Peak Discharge (cu.m/s)
# Pre-Dev:  22.4057
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# g:\ab\development\programs\python\settings\.virtualenvs\tuflow-graphing-b2xgbx1t\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'C 1-3'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-b21d1047c88b> in <module>
#       1 print('Peak Discharge (cu.m/s)')
#       2 print('Pre-Dev: ', np.max(df_dataset_s00[sample_point]))
# ----> 3 print('Pre-Dev: ', np.max(df_dataset_s01[sample_point]))
#
# g:\ab\development\programs\python\settings\.virtualenvs\tuflow-graphing-b2xgbx1t\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# g:\ab\development\programs\python\settings\.virtualenvs\tuflow-graphing-b2xgbx1t\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# g:\ab\development\programs\python\settings\.virtualenvs\tuflow-graphing-b2xgbx1t\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# g:\ab\development\programs\python\settings\.virtualenvs\tuflow-graphing-b2xgbx1t\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# g:\ab\development\programs\python\settings\.virtualenvs\tuflow-graphing-b2xgbx1t\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'C 1-3'

# %% [markdown]
# ###### Volume of Runoff at Location
# * Based on Trapezoidal Rule within NumPy

# %%
print('Volume of Runoff (cu.m)')
print('Pre-Dev: ', np.trapz(df_dataset_s00[sample_point], dx = 60))
print('Pre-Dev: ', np.trapz(df_dataset_s01[sample_point], dx = 60))

# %% [markdown]
# ###### Volume difference between Pre- and Post-Development Runoff

# %%
print('Approximate Basin Volume (cu.m)')
print('Volume: ', np.trapz(df_dataset_s01[sample_point], dx = 60) - np.trapz(df_dataset_s00[sample_point], dx = 60))
